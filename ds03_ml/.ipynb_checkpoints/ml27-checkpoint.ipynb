# %%
from sklearn.datasets import make_moons, load_breast_cancer
from sklearn. model_selection import train_test_split
from sklearn. ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# make_moons:연습용 데이터 생성
x, y = make_moons(n_samples=1000, noise=0.25, random_state=1)

# %%
plt.plot(x[y==1, 0], x[y==1, 1], marker="o", color="red", linestyle="")
plt.plot(x[y==0, 0], x[y==0, 1], marker="o", color="blue", linestyle="")
plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=1)
# test_size= 안써주면 네가 알아서 해봐 라는 것

# %%
# 모델 선택
model = RandomForestClassifier(n_estimators=5)
#

# %%
# 모델 학습
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=5)

# %%
predict = model.predict(x_test)
accuracy_score(y_test, predict)
# Out:
# 0.912

# %%
model.estimators_
# Out:
# [DecisionTreeClassifier(max_features='sqrt', random_state=813300018),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2042401632),
#  DecisionTreeClassifier(max_features='sqrt', random_state=247922732),
#  DecisionTreeClassifier(max_features='sqrt', random_state=16974133),
#  DecisionTreeClassifier(max_features='sqrt', random_state=87353598)]

# %%
cancer = load_breast_cancer()
# 유방암

# %%
x_train, x_test, y_train, y_test = train_test_split(cancer.data, cancer.target, test_size=0.3, random_state=1)

# %%
model = RandomForestClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
predict = model.predict(x_test)
accuracy_score(y_test, predict)
#  accuracy_score 정확도 평가
# Out:
# 0.9532163742690059

# %%
sns.barplot(x=model.feature_importances_, y=cancer.feature_names)
# Out:
# <Axes: >
